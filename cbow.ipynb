# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.models import Model
import numpy as np 
import pandas as pd 
import re
import nltk
from preprocess import *
# from models import *

# %%
df = pd.read_csv("questions.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
# question_1, question_2 = df['question1'].to_list(), df['question2'].to_list()
# is_duplicate = df['is_duplicate'].to_list()
# preprocess_neural(question_1, question_2, is_duplicate)

# %%
df1 = pd.read_csv("preprocessed_neural.csv")
q1_preprocessed, q2_preprocessed, is_duplicate = df1['question1'].to_list(), df1['question2'].to_list(), df1['is_duplicate'].to_list()

# %%
df1.head()
# Out:
#                                            question1  \
# 0          step step guide invest share market india
# 1                    story kohinoor kohinoor diamond
# 2       increase speed internet connection using vpn
# 3                              mentally lonely solve
# 4  one dissolve water quikly sugar salt methane c...
#
#                                            question2  is_duplicate
# 0                step step guide invest share market             0
# 1  would happen indian government stole kohinoor ...             0
# 2               internet speed increased hacking dns             0
# 3           find remainder math2324math divided 2423             0
# 4                      fish would survive salt water             0

# %% [markdown]
# Acquired Test data

# %%
MAX_NB_WORDS = 200000
tokenizer = Tokenizer(num_words = MAX_NB_WORDS)
tokenizer.fit_on_texts(list(df1['question1'].values.astype(str))+list(df1['question2'].values.astype(str)))

# %%
q1_sequence = tokenizer.texts_to_sequences(df['question1'].values.astype(str))
q1_sequence = pad_sequences(q1_sequence, maxlen = 30, padding='post')

q2_sequence = tokenizer.texts_to_sequences(df['question2'].values.astype(str))
q2_sequence = pad_sequences(q2_sequence, maxlen = 30, padding='post')

# %%
windex = tokenizer.word_index

# %%
embedding_index = {}
with open('glove.6B.300d.txt','r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:], 'float32')
        embedding_index[word] = vectors
    f.close()

# %%
embedding_matrix = np.random.random((len(windex)+1, 300))

for word, i in windex.items():
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (108101, 300)

# %%
q1_embeddings = []
for i in range(len(q1_sequence)):
    embedding = np.zeros(300)
    for j in range(len(q1_sequence[i])):
        embedding += embedding_matrix[q1_sequence[i][j]]
    embedding /= len(q1_sequence[i])
    q1_embeddings.append(embedding)

q2_embeddings = []
for i in range(len(q2_sequence)):
    embedding = np.zeros(300)
    for j in range(len(q2_sequence[i])):
        embedding += embedding_matrix[q2_sequence[i][j]]
    embedding /= len(q2_sequence[i])
    q2_embeddings.append(embedding)

# %%
# change all 0 to 0 1 and 1 to 1 0
for i in range(len(is_duplicate)):
    if is_duplicate[i] == 0:
        is_duplicate[i] = [0,1]
    else:
        is_duplicate[i] = [1,0]

# %%
#split the data into 70-20-10 train-validation-test with random state 42
from sklearn.model_selection import train_test_split
q1_train, q1_test, q2_train, q2_test, y_train, y_test = train_test_split(q1_embeddings, q2_embeddings, is_duplicate, test_size=0.1, random_state=42)
q1_train, q1_val, q2_train, q2_val, y_train, y_val = train_test_split(q1_train, q2_train, y_train, test_size=0.222, random_state=42)

# %%
#print the ratio of positive and negative samples in train, validation and test
y_train, y_val, y_test = np.array(y_train), np.array(y_val), np.array(y_test)
print("Train: ", sum(y_train)/len(y_train))
print("Validation: ", sum(y_val)/len(y_val))
print("Test: ", sum(y_test)/len(y_test))
# Out:
# Train:  [0.36970243 0.63029757]
# Validation:  [0.36774353 0.63225647]
# Test:  [0.36907706 0.63092294]

# %%
def concatenate_embeddings(q1_embeddings, q2_embeddings):
    embeddings = np.zeros((len(q1_embeddings), 900))
    for i in range(len(q1_embeddings)):
        for j in range(0, 300):
            embeddings[i][j] = q1_embeddings[i][j] + q2_embeddings[i][j]
        for j in range(300, 600):
            embeddings[i][j] = q1_embeddings[i][j-300] - q2_embeddings[i][j-300]
        for j in range(600, 900):
            embeddings[i][j] = q1_embeddings[i][j-600] * q2_embeddings[i][j-600]
    return embeddings
xtrain_concat = concatenate_embeddings(q1_train, q2_train)
xval_concat = concatenate_embeddings(q1_val, q2_val)
xtest_concat = concatenate_embeddings(q1_test, q2_test)

# %%
print(xval_concat.shape)
print(xtrain_concat.shape)
# Out:
# (80790, 900)
# (283125, 900)

# %%
# %load models.py
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.models import Model
import tensorflow as tf
import numpy as np 
from keras import Sequential

class NeuralModels:
    def __init__(self, emb_mat, vocab_size = -1, loss = "binary_crossentropy", epochs = 10, optimizer = "adam", metrics = ["accuracy"]):
        self.epochs = epochs
        self.optimizer = optimizer
        self.loss = loss
        self.metrics = metrics
        self.vocab_size = vocab_size
        self.embedding_matrix = emb_mat
        self.model = Sequential()

class CBOW(NeuralModels):
    def __init__(self, emb_mat, vocab_size = -1, loss = "binary_crossentropy", epochs = 10, optimizer = "adam", metrics = ["accuracy"]):
        super().__init__(emb_mat, vocab_size, loss, epochs, optimizer, metrics)
    
    def fit(self,xtrain, xval, ytrain, yval):
        self.model.add(Dense(300, input_shape = (900,), activation = "relu"))
        self.model.add(Dropout(0.1))
        self.model.add(Dense(200, activation = "relu"))
        self.model.add(Dropout(0.1))
        self.model.add(Dense(100, activation = "relu"))
        self.model.add(Dropout(0.1))
        self.model.add(Dense(2, activation = "softmax"))
        self.model.compile(loss = self.loss, optimizer = self.optimizer, metrics = self.metrics)
        self.model.fit(xtrain, ytrain, epochs = self.epochs, validation_data = (xval, yval), batch_size = 64, verbose = 1)

    def get_model_summary(self):
        self.model.summary()
    
    def predict(self, xtest):
        return self.model.predict(xtest)

# %%
model = CBOW(embedding_matrix, embedding_matrix.shape[0], loss="binary_crossentropy", epochs=50)

# %%
xtrain_concat, xval_concat, y_train, y_val = np.array(xtrain_concat), np.array(xval_concat), np.array(y_train), np.array(y_val)
model.fit(xtrain_concat, xval_concat, y_train, y_val)
# Out:
# 2022-12-01 05:37:24.216939: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1019250000 exceeds 10% of free system memory.
# Epoch 1/50
# 4424/4424 [==============================] - 31s 7ms/step - loss: 0.6166 - accuracy: 0.6398 - val_loss: 0.5858 - val_accuracy: 0.6839
# Epoch 2/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5862 - accuracy: 0.6716 - val_loss: 0.5741 - val_accuracy: 0.6910
# Epoch 3/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.
50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5118 - accuracy: 0.7325 - val_loss: 0.5143 - val_accuracy: 0.7336
# Epoch 29/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5116 - accuracy: 0.7318 - val_loss: 0.5029 - val_accuracy: 0.7424
# Epoch 30/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5093 - accuracy: 0.7343 - val_loss: 0.4988 - val_accuracy: 0.7431
# Epoch 31/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5101 - accuracy: 0.7335 - val_loss: 0.4998 - val_accuracy: 0.7446
# Epoch 32/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5085 - accuracy: 0.7335 - val_loss: 0.4988 - val_accuracy: 0.7464
# Epoch 33/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5083 - accuracy: 0.7343 - val_loss: 0.5060 - val_accuracy: 0.7416
# Epoch 34/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5075 - accuracy: 0.7350 - val_loss: 0.5020 - val_accuracy: 0.7393
# Epoch 35/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5063 - accuracy: 0.7362 - val_loss: 0.4980 - val_accuracy: 0.7460
# Epoch 36/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5046 - accuracy: 0.7379 - val_loss: 0.5155 - val_accuracy: 0.7322
# Epoch 37/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5043 - accuracy: 0.7375 - val_loss: 0.4973 - val_accuracy: 0.7447
# Epoch 38/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5041 - accuracy: 0.7377 - val_loss: 0.5008 - val_accuracy: 0.7379
# Epoch 39/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5034 - accuracy: 0.7387 - val_loss: 0.5096 - val_accuracy: 0.7365
# Epoch 40/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5027 - accuracy: 0.7394 - val_loss: 0.4954 - val_accuracy: 0.7491
# Epoch 41/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5034 - accuracy: 0.7379 - val_loss: 0.4953 - val_accuracy: 0.7499
# Epoch 42/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5018 - accuracy: 0.7388 - val_loss: 0.5013 - val_accuracy: 0.7413
# Epoch 43/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5012 - accuracy: 0.7397 - val_loss: 0.5031 - val_accuracy: 0.7427
# Epoch 44/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5014 - accuracy: 0.7392 - val_loss: 0.4950 - val_accuracy: 0.7475
# Epoch 45/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4994 - accuracy: 0.7413 - val_loss: 0.4970 - val_accuracy: 0.7465
# Epoch 46/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4995 - accuracy: 0.7411 - val_loss: 0.5036 - val_accuracy: 0.7384
# Epoch 47/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4995 - accuracy: 0.7415 - val_loss: 0.5056 - val_accuracy: 0.7382
# Epoch 48/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4996 - accuracy: 0.7408 - val_loss: 0.5029 - val_accuracy: 0.7422
# Epoch 49/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4990 - accuracy: 0.7416 - val_loss: 0.4990 - val_accuracy: 0.7446
# Epoch 50/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4993 - accuracy: 0.7412 - val_loss: 0.4964 - val_accuracy: 0.7484

# %%
y_pred = model.predict(xtest_concat)
y_pred1d = []
for i in range(len(y_pred)):
    if(y_pred[i][0] > y_pred[i][1]):
        y_pred1d.append(0)
    else:
        y_pred1d.append(1)

y_test1d = []
for i in range(len(y_test)):
    if(y_test[i][0] > y_test[i][1]):
        y_test1d.append(0)
    else:
        y_test1d.append(1)

from sklearn.metrics import accuracy_score, f1_score
print("Accuracy: ", accuracy_score(y_test1d, y_pred1d))
print("F1 Score: ", f1_score(y_test1d, y_pred1d))
# Out:
# 1264/1264 [==============================] - 4s 2ms/step
# Accuracy:  0.7509397566524879
# F1 Score:  0.8059201017517489
