# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.models import Model
import numpy as np 
import pandas as pd 
import re
import nltk
from preprocess import *
from models import *

# %%
df = pd.read_csv("questions.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
# question_1, question_2 = df['question1'].to_list(), df['question2'].to_list()
# is_duplicate = df['is_duplicate'].to_list()
# preprocess_neural(question_1, question_2, is_duplicate)

# %%
df1 = pd.read_csv("preprocessed_neural.csv")
q1_preprocessed, q2_preprocessed, is_duplicate = df1['question1'].to_list(), df1['question2'].to_list(), df1['is_duplicate'].to_list()

# %%
df1.head()
# Out:
#                                            question1  \
# 0          step step guide invest share market india
# 1                    story kohinoor kohinoor diamond
# 2       increase speed internet connection using vpn
# 3                              mentally lonely solve
# 4  one dissolve water quikly sugar salt methane c...
#
#                                            question2  is_duplicate
# 0                step step guide invest share market             0
# 1  would happen indian government stole kohinoor ...             0
# 2               internet speed increased hacking dns             0
# 3           find remainder math2324math divided 2423             0
# 4                      fish would survive salt water             0

# %% [markdown]
# Acquired Test data

# %%
MAX_NB_WORDS = 200000
tokenizer = Tokenizer(num_words = MAX_NB_WORDS)
tokenizer.fit_on_texts(list(df1['question1'].values.astype(str))+list(df1['question2'].values.astype(str)))

# %%
q1_sequence = tokenizer.texts_to_sequences(df['question1'].values.astype(str))
q1_sequence = pad_sequences(q1_sequence, maxlen = 30, padding='post')

q2_sequence = tokenizer.texts_to_sequences(df['question2'].values.astype(str))
q2_sequence = pad_sequences(q2_sequence, maxlen = 30, padding='post')

# %%
windex = tokenizer.word_index

# %%
embedding_index = {}
with open('glove.6B.300d.txt','r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:], 'float32')
        embedding_index[word] = vectors
    f.close()

# %%
embedding_matrix = np.random.random((len(windex)+1, 300))

for word, i in windex.items():
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (108101, 300)

# %%
q1_embeddings = []
for i in range(len(q1_sequence)):
    embedding = np.zeros(300)
    for j in range(len(q1_sequence[i])):
        embedding += embedding_matrix[q1_sequence[i][j]]
    embedding /= len(q1_sequence[i])
    q1_embeddings.append(embedding)

q2_embeddings = []
for i in range(len(q2_sequence)):
    embedding = np.zeros(300)
    for j in range(len(q2_sequence[i])):
        embedding += embedding_matrix[q2_sequence[i][j]]
    embedding /= len(q2_sequence[i])
    q2_embeddings.append(embedding)

# %%
# change all 0 to 0 1 and 1 to 1 0
for i in range(len(is_duplicate)):
    if is_duplicate[i] == 0:
        is_duplicate[i] = [0,1]
    else:
        is_duplicate[i] = [1,0]

# %%
#split the data into 70-20-10 train-validation-test with random state 42
from sklearn.model_selection import train_test_split
q1_train, q1_test, q2_train, q2_test, y_train, y_test = train_test_split(q1_embeddings, q2_embeddings, is_duplicate, test_size=0.1, random_state=42)
q1_train, q1_val, q2_train, q2_val, y_train, y_val = train_test_split(q1_train, q2_train, y_train, test_size=0.222, random_state=42)

# %%
#print the ratio of positive and negative samples in train, validation and test
y_train, y_val, y_test = np.array(y_train), np.array(y_val), np.array(y_test)
print("Train: ", sum(y_train)/len(y_train))
print("Validation: ", sum(y_val)/len(y_val))
print("Test: ", sum(y_test)/len(y_test))
# Out:
# Train:  [0.36970243 0.63029757]
# Validation:  [0.36774353 0.63225647]
# Test:  [0.36907706 0.63092294]

# %%
def concatenate_embeddings(q1_embeddings, q2_embeddings):
    embeddings = np.zeros((len(q1_embeddings), 900))
    for i in range(len(q1_embeddings)):
        for j in range(0, 300):
            embeddings[i][j] = q1_embeddings[i][j] + q2_embeddings[i][j]
        for j in range(300, 600):
            embeddings[i][j] = q1_embeddings[i][j-300] - q2_embeddings[i][j-300]
        for j in range(600, 900):
            embeddings[i][j] = q1_embeddings[i][j-600] * q2_embeddings[i][j-600]
    return embeddings
xtrain_concat = concatenate_embeddings(q1_train, q2_train)
xval_concat = concatenate_embeddings(q1_val, q2_val)
xtest_concat = concatenate_embeddings(q1_test, q2_test)

# %%
print(xval_concat.shape)
print(xtrain_concat.shape)
# Out:
# (80790, 900)
# (283125, 900)

# %%
model = CBOW(embedding_matrix, embedding_matrix.shape[0], loss="binary_crossentropy", epochs=50)

# %%
xtrain_concat, xval_concat, y_train, y_val = np.array(xtrain_concat), np.array(xval_concat), np.array(y_train), np.array(y_val)
model.fit(xtrain_concat, xval_concat, y_train, y_val)
# Out:
# Epoch 1/50
# 4424/4424 [==============================] - 33s 7ms/step - loss: 0.6112 - accuracy: 0.6469 - val_loss: 0.5797 - val_accuracy: 0.6872
# Epoch 2/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5829 - accuracy: 0.6789 - val_loss: 0.5767 - val_accuracy: 0.6918
# Epoch 3/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5708 - accuracy: 0.6884 - val_loss: 0.5591 - val_accuracy: 0.7032
# Epoch 4/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5603 - accuracy: 0.6969 - val_loss: 0.5462 - val_accuracy: 0.7106
# Epoch 5/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5534 - accuracy: 0.7013 - val_loss: 0.5461 - val_accuracy: 0.7069
# Epoch 6/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5469 - accuracy: 0.7060 - val_loss: 0.5344 - val_accuracy: 0.7168
# Epoch 7/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5390 - accuracy: 0.7115 - val_loss: 0.5537 - val_accuracy: 0.6719
# Epoch 8/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5333 - accuracy: 0.7152 - val_loss: 0.5252 - val_accuracy: 0.7224
# Epoch 9/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5278 - accuracy: 0.7175 - val_loss: 0.5218 - val_accuracy: 0.7315
# Epoch 10/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5224 - accuracy: 0.7220 - val_loss: 0.5217 - val_accuracy: 0.7196
# Epoch 11/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5186 - accuracy: 0.7247 - val_loss: 0.5157 - val_accuracy: 0.7147
# Epoch 12/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5128 - accuracy: 0.7291 - val_loss: 0.5350 - val_accuracy: 0.7194
# Epoch 13/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.5102 - accuracy: 0.7303 - val_loss: 0.4967 - val_accuracy: 0.7425
# Epoch 14/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5062 - accuracy: 0.7328 - val_loss: 0.4953 - val_accuracy: 0.7428
# Epoch 15/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.5025 - accuracy: 0.7357 - val_loss: 0.5060 - val_accuracy: 0.7336
# Epoch 16/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4993 - accuracy: 0.7381 - val_loss: 0.4898 - val_accuracy: 0.7464
# Epoch 17/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4971 - accuracy: 0.7394 - val_loss: 0.5019 - val_accuracy: 0.7401
# Epoch 18/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4952 - accuracy: 0.7406 - val_loss: 0.5033 - val_accuracy: 0.7374
# Epoch 19/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4929 - accuracy: 0.7416 - val_loss: 0.4866 - val_accuracy: 0.7502
# Epoch 20/50
# 4424/4424 [==============================] - 28s 6ms/step - loss: 0.4904 - accuracy: 0.7445 - val_loss: 0.5035 - val_accuracy: 0.7380
# Epoch 21/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4869 - accuracy: 0.7461 - val_loss: 0.4812 - val_accuracy: 0.7534
# Epoch 22/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4849 - accuracy: 0.7471 - val_loss: 0.4808 - val_accuracy: 0.7521
# Epoch 23/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4825 - accuracy: 0.7495 - val_loss: 0.4793 - val_accuracy: 0.7549
# Epoch 24/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4802 - accuracy: 0.7503 - val_loss: 0.4783 - val_accuracy: 0.7544
# Epoch 25/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4780 - accuracy: 0.7520 - val_loss: 0.4769 - val_accuracy: 0.7562
# Epoch 26/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4758 - accuracy: 0.7538 - val_loss: 0.4923 - val_accuracy: 0.7373
# Epoch 27/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4737 - accuracy: 0.7543 - val_loss: 0.4706 - val_accuracy: 0.7606
# Epoch 28/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4717 - accuracy: 0.7564 - val_loss: 0.4804 - val_accuracy: 0.7495
# Epoch 29/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4696 - accuracy: 0.7573 - val_loss: 0.4776 - val_accuracy: 0.7574
# Epoch 30/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4679 - accuracy: 0.7588 - val_loss: 0.4657 - val_accuracy: 0.7642
# Epoch 31/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4662 - accuracy: 0.7598 - val_loss: 0.4762 - val_accuracy: 0.7541
# Epoch 32/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4636 - accuracy: 0.7617 - val_loss: 0.4811 - val_accuracy: 0.7520
# Epoch 33/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4617 - accuracy: 0.7624 - val_loss: 0.4716 - val_accuracy: 0.7615
# Epoch 34/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4604 - accuracy: 0.7641 - val_loss: 0.4698 - val_accuracy: 0.7574
# Epoch 35/50
# 4424/4424 [==============================] - 26s 6ms/step - loss: 0.4588 - accuracy: 0.7646 - val_loss: 0.4794 - val_accuracy: 0.7482
# Epoch 36/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4574 - accuracy: 0.7661 - val_loss: 0.4644 - val_accuracy: 0.7624
# Epoch 37/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4557 - accuracy: 0.7670 - val_loss: 0.4658 - val_accuracy: 0.7634
# Epoch 38/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4542 - accuracy: 0.7683 - val_loss: 0.4753 - val_accuracy: 0.7501
# Epoch 39/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4533 - accuracy: 0.7674 - val_loss: 0.4726 - val_accuracy: 0.7578
# Epoch 40/50
# 4424/4424 [==============================] - 28s 6ms/step - loss: 0.4510 - accuracy: 0.7694 - val_loss: 0.4674 - val_accuracy: 0.7589
# Epoch 41/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4503 - accuracy: 0.7708 - val_loss: 0.4536 - val_accuracy: 0.7720
# Epoch 42/50
# 4424/4424 [==============================] - 31s 7ms/step - loss: 0.4480 - accuracy: 0.7711 - val_loss: 0.4560 - val_accuracy: 0.7709
# Epoch 43/50
# 4424/4424 [==============================] - 28s 6ms/step - loss: 0.4474 - accuracy: 0.7722 - val_loss: 0.4523 - val_accuracy: 0.7721
# Epoch 44/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4447 - accuracy: 0.7738 - val_loss: 0.4548 - val_accuracy: 0.7715
# Epoch 45/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4428 - accuracy: 0.7747 - val_loss: 0.4462 - val_accuracy: 0.7777
# Epoch 46/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4421 - accuracy: 0.7745 - val_loss: 0.4524 - val_accuracy: 0.7728
# Epoch 47/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4408 - accuracy: 0.7754 - val_loss: 0.4532 - val_accuracy: 0.7720
# Epoch 48/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4389 - accuracy: 0.7775 - val_loss: 0.4630 - val_accuracy: 0.7730
# Epoch 49/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4382 - accuracy: 0.7776 - val_loss: 0.4498 - val_accuracy: 0.7751
# Epoch 50/50
# 4424/4424 [==============================] - 27s 6ms/step - loss: 0.4374 - accuracy: 0.7780 - val_loss: 0.4462 - val_accuracy: 0.7762

# %%
y_pred = model.predict(xtest_concat)
y_pred1d = []
for i in range(len(y_pred)):
    if(y_pred[i][0] > y_pred[i][1]):
        y_pred1d.append(0)
    else:
        y_pred1d.append(1)

y_test1d = []
for i in range(len(y_test)):
    if(y_test[i][0] > y_test[i][1]):
        y_test1d.append(0)
    else:
        y_test1d.append(1)

from sklearn.metrics import accuracy_score, f1_score
print("Accuracy: ", accuracy_score(y_test1d, y_pred1d))
print("F1 Score: ", f1_score(y_test1d, y_pred1d))
# Out:
# 1264/1264 [==============================] - 2s 2ms/step
# Accuracy:  0.7762884558314374
# F1 Score:  0.8167044901929
