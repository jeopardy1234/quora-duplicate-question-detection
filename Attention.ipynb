# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.models import Model
import numpy as np 
import pandas as pd 
import re
import nltk
from preprocess import *
from models import *
# Out:
# 2022-12-01 22:01:59.670829: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-01 22:02:01.334620: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-12-01 22:02:01.334711: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-12-01 22:02:01.334719: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
df = pd.read_csv("questions.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
# question_1, question_2 = df['question1'].to_list(), df['question2'].to_list()
# is_duplicate = df['is_duplicate'].to_list()
# preprocess_neural(question_1, question_2, is_duplicate)

# %%
df1 = pd.read_csv("preprocessed_neural.csv")
q1_preprocessed, q2_preprocessed, is_duplicate = df1['question1'].to_list(), df1['question2'].to_list(), df1['is_duplicate'].to_list()

# %%
# change all 0 to 0 1 and 1 to 1 0
for i in range(len(is_duplicate)):
    if is_duplicate[i] == 0:
        is_duplicate[i] = [0,1]
    else:
        is_duplicate[i] = [1,0]

# %% [markdown]
# Acquired Test data

# %%
MAX_WORDS_VOCAB = 200000
tokenizer = Tokenizer(num_words = MAX_WORDS_VOCAB)
tokenizer.fit_on_texts(list(df1['question1'].values.astype(str))+list(df1['question2'].values.astype(str)))

# %%
q1_sequence = tokenizer.texts_to_sequences(df['question1'].values.astype(str))
q1_sequence = pad_sequences(q1_sequence, maxlen = 30, padding='post')

q2_sequence = tokenizer.texts_to_sequences(df['question2'].values.astype(str))
q2_sequence = pad_sequences(q2_sequence, maxlen = 30, padding='post')

# %%
windex = tokenizer.word_index

# %%
embedding_index = {}
with open('glove.6B.300d.txt','r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:], 'float32')
        embedding_index[word] = vectors
    f.close()

# %%
embedding_matrix = np.random.random((len(windex)+1, 300))

for word, i in windex.items():
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (108101, 300)

# %%
#split the data into 70-20-10 train-validation-test with random state 42
from sklearn.model_selection import train_test_split
q1_train, q1_test, q2_train, q2_test, y_train, y_test = train_test_split(q1_sequence, q2_sequence, is_duplicate, test_size=0.1, random_state=42)
q1_train, q1_val, q2_train, q2_val, y_train, y_val = train_test_split(q1_train, q2_train, y_train, test_size=0.2, random_state=42)

# %%
print(q1_train.shape, q1_test.shape, q1_val.shape)
# Out:
# (291132, 30) (40436, 30) (72783, 30)

# %%
#print the ratio of positive and negative samples in train, validation and test
y_train, y_val, y_test = np.array(y_train), np.array(y_val), np.array(y_test)
print("Train: ", sum(y_train)/len(y_train))
print("Validation: ", sum(y_val)/len(y_val))
print("Test: ", sum(y_test)/len(y_test))
# Out:
# Train:  [0.36998338 0.63001662]
# Validation:  [0.36640424 0.63359576]
# Test:  [0.36907706 0.63092294]

# %%
lstm_attention = LSTM_Attention(embedding_matrix, len(windex) + 1, loss = "binary_crossentropy", epochs = 4, optimizer = "adam", metrics = ["accuracy"])
# Out:
# 2022-12-01 22:03:37.200756: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-12-01 22:03:37.201907: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pop-os): /proc/driver/nvidia/version does not exist
# 2022-12-01 22:03:37.209171: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
lstm_attention.train_model()
# Out:
# 2022-12-01 22:03:42.212262: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 129721200 exceeds 10% of free system memory.
# 2022-12-01 22:03:42.274354: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 129721200 exceeds 10% of free system memory.
# 2022-12-01 22:03:42.336051: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 129721200 exceeds 10% of free system memory.
# 2022-12-01 22:03:42.589318: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 129721200 exceeds 10% of free system memory.
# 2022-12-01 22:03:42.669242: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 129721200 exceeds 10% of free system memory.

# %%
lstm_attention.get_model_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      32430300    input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 30, 300)      32430300    input_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 30, 300)      0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 30, 300)      0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 30, 300)      0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 900)      0           tf.__operators__.add[0][0]
#                                                                  tf.math.subtract[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape (TFOpLambda) (3,)                 0           concatenate[0][0]
# __________________________________________________________________________________________________
# tf.ones_like (TFOpLambda)       (None, 30, 900)      0           concatenate[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici ()                   0           tf.compat.v1.shape[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 30, 900)      0           concatenate[0][0]
#                                                                  tf.ones_like[0][0]
# __________________________________________________________________________________________________
# tf.zeros (TFOpLambda)           (None, 150)          0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.zeros_1 (TFOpLambda)         (None, 150)          0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# tf.keras.backend.rnn (TFOpLambd ((None, 150), (None, 0           tf.math.multiply_1[0][0]
#                                                                  tf.zeros[0][0]
#                                                                  tf.zeros_1[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 30, 30)       0           tf.keras.backend.rnn[0][1]
#                                                                  tf.keras.backend.rnn[0][1]
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 30, 30)       0           tf.linalg.matmul[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_1 (TFOpLambda) (None, 30, 150)      0           tf.nn.softmax[0][0]
#                                                                  tf.keras.backend.rnn[0][1]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 150)          0           tf.linalg.matmul_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            302         tf.math.reduce_mean[0][0]
# ==================================================================================================
# Total params: 64,860,902
# Trainable params: 302
# Non-trainable params: 64,860,600
# __________________________________________________________________________________________________

# %%
lstm_attention.model.fit([q1_train, q2_train], y_train, epochs = 4, validation_data = ([q1_val, q2_val], y_val), batch_size = 8, validation_batch_size=4, verbose = 1)
# Out:
# Epoch 1/4
# 36392/36392 [==============================] - 284s 8ms/step - loss: 0.6509 - accuracy: 0.6299 - val_loss: 0.6469 - val_accuracy: 0.6336
# Epoch 2/4
# 36392/36392 [==============================] - 291s 8ms/step - loss: 0.6496 - accuracy: 0.6297 - val_loss: 0.6530 - val_accuracy: 0.6328
# Epoch 3/4
# 36392/36392 [==============================] - 282s 8ms/step - loss: 0.6498 - accuracy: 0.6297 - val_loss: 0.6470 - val_accuracy: 0.6336
# Epoch 4/4
# 36392/36392 [==============================] - 281s 8ms/step - loss: 0.6497 - accuracy: 0.6297 - val_loss: 0.6476 - val_accuracy: 0.6336

# %%
y_pred = lstm_attention.predict([q1_test, q2_test])
y_pred1d, y_actual1d = [], []
for i in range(len(y_test)):
    if(y_test[i][0] == 1):
        y_actual1d.append(0)
    else:
        y_actual1d.append(1)

for i in range(len(y_pred)):
    if(y_pred[i][0] > y_pred[i][1]):
        y_pred1d.append(0)
    else:
        y_pred1d.append(1)

from sklearn.metrics import accuracy_score, f1_score
print("Accuracy: ", accuracy_score(y_actual1d, y_pred1d))
print("F1 Score: ", f1_score(y_actual1d, y_pred1d))
# Out:
# Accuracy:  0.630922939954496
# F1 Score:  0.7737004912961728

# %%
bilstm_attention = BiLSTM_Attention(embedding_matrix, len(windex) + 1, loss = "binary_crossentropy", epochs = 4, optimizer = "adam", metrics = ["accuracy"])

# %%
bilstm_attention.train_model()

# %%
bilstm_attention.get_model_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 30, 300)      32430300    input_3[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 30, 300)      32430300    input_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 30, 300)      0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 30, 300)      0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 30, 300)      0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 900)      0           tf.__operators__.add_1[0][0]
#                                                                  tf.math.subtract_1[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_4 (TFOpLambd (3,)                 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_2 (TFOpLambd (3,)                 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.ones_like_2 (TFOpLambda)     (None, 30, 900)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli ()                   0           tf.compat.v1.shape_4[0][0]
# __________________________________________________________________________________________________
# tf.ones_like_1 (TFOpLambda)     (None, 30, 900)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli ()                   0           tf.compat.v1.shape_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 30, 900)      0           concatenate_1[0][0]
#                                                                  tf.ones_like_2[0][0]
# __________________________________________________________________________________________________
# tf.zeros_4 (TFOpLambda)         (None, 150)          0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.zeros_5 (TFOpLambda)         (None, 150)          0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 30, 900)      0           concatenate_1[0][0]
#                                                                  tf.ones_like_1[0][0]
# __________________________________________________________________________________________________
# tf.zeros_2 (TFOpLambda)         (None, 150)          0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.zeros_3 (TFOpLambda)         (None, 150)          0           tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# tf.keras.backend.rnn_2 (TFOpLam ((None, 150), (None, 0           tf.math.multiply_4[0][0]
#                                                                  tf.zeros_4[0][0]
#                                                                  tf.zeros_5[0][0]
# __________________________________________________________________________________________________
# tf.keras.backend.rnn_1 (TFOpLam ((None, 150), (None, 0           tf.math.multiply_3[0][0]
#                                                                  tf.zeros_2[0][0]
#                                                                  tf.zeros_3[0][0]
# __________________________________________________________________________________________________
# tf.reverse (TFOpLambda)         (None, 30, 150)      0           tf.keras.backend.rnn_2[0][1]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 30, 300)      0           tf.keras.backend.rnn_1[0][1]
#                                                                  tf.reverse[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_2 (TFOpLambda) (None, 30, 30)       0           tf.concat[0][0]
#                                                                  tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax_1 (TFOpLambda)    (None, 30, 30)       0           tf.linalg.matmul_2[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_3 (TFOpLambda) (None, 30, 300)      0           tf.nn.softmax_1[0][0]
#                                                                  tf.concat[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 300)          0           tf.linalg.matmul_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            602         tf.math.reduce_mean_1[0][0]
# ==================================================================================================
# Total params: 64,861,202
# Trainable params: 602
# Non-trainable params: 64,860,600
# __________________________________________________________________________________________________

# %%
bilstm_attention.model.fit([q1_train, q2_train], y_train, epochs = 5, validation_data = ([q1_val, q2_val], y_val), batch_size = 8, validation_batch_size=4, verbose = 1)
# Out:
# Epoch 1/5
# 36392/36392 [==============================] - 558s 15ms/step - loss: 0.6542 - accuracy: 0.6290 - val_loss: 0.6457 - val_accuracy: 0.6336
# Epoch 2/5
# 36392/36392 [==============================] - 521s 14ms/step - loss: 0.6491 - accuracy: 0.6285 - val_loss: 0.6443 - val_accuracy: 0.6336
# Epoch 3/5
# 36392/36392 [==============================] - 553s 15ms/step - loss: 0.6478 - accuracy: 0.6284 - val_loss: 0.6431 - val_accuracy: 0.6336
# Epoch 4/5
# 36392/36392 [==============================] - 509s 14ms/step - loss: 0.6474 - accuracy: 0.6281 - val_loss: 0.6520 - val_accuracy: 0.6336
# Epoch 5/5
# 36392/36392 [==============================] - 510s 14ms/step - loss: 0.6473 - accuracy: 0.6283 - val_loss: 0.6428 - val_accuracy: 0.6336

# %%
y_pred = bilstm_attention.predict([q1_test, q2_test])
y_pred1d, y_actual1d = [], []
for i in range(len(y_test)):
    if(y_test[i][0] == 1):
        y_actual1d.append(0)
    else:
        y_actual1d.append(1)

for i in range(len(y_pred)):
    if(y_pred[i][0] > y_pred[i][1]):
        y_pred1d.append(0)
    else:
        y_pred1d.append(1)

from sklearn.metrics import accuracy_score, f1_score
print("Accuracy: ", accuracy_score(y_actual1d, y_pred1d))
print("F1 Score: ", f1_score(y_actual1d, y_pred1d))
# Out:
# Accuracy:  0.630922939954496
# F1 Score:  0.7737004912961728
